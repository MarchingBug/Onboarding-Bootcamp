# %% [markdown]
# # Bronze: Ingest Synthetic Data

# %%
import pandas as pd
trades=pd.read_csv('../../industry/capital_markets/trades.csv')
claims=pd.read_csv('../../industry/insurance/claims.csv')
customers=pd.read_csv('../../industry/banking/customers.csv')
transactions=pd.read_csv('../../industry/banking/transactions.csv')
print(trades.head())
print(claims.head())
