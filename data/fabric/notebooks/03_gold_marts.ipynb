# %% [markdown]
# # Gold: Feature Marts for Agents

# %%
import pandas as pd
silver=pd.read_csv('../silver_trades.csv')
# Simple anomaly flag
silver['anomaly_flag']=(silver['notional']>250000).astype(int)
silver.to_csv('../gold_trades_mart.csv',index=False)
print('Wrote gold_trades_mart.csv')
