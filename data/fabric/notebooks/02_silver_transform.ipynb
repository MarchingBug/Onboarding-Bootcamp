# %% [markdown]
# # Silver: Clean & Normalize

# %%
import pandas as pd
trades=pd.read_csv('../../industry/capital_markets/trades.csv')
trades['notional']=trades['qty']*trades['price']
trades.to_csv('../silver_trades.csv',index=False)
print('Wrote silver_trades.csv')
